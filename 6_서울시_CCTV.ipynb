# %% [markdown]
# <a href="https://colab.research.google.com/github/MANDOJU1/pandas/blob/main/6_%EC%84%9C%EC%9A%B8%EC%8B%9C_CCTV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 데이터 셋 수집
# - 서울 열린 데이터 광장
#   - 서울시 5대 범죄 발생현황
#   - 자치구 년도별 cctv 설치현황
#   - 주민등록인구(구별) 통계

# %%
# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 한글 폰트 설정
# import koreanize_matplotlib

import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## 데이터 로드

# %%
## cctv

df_cctv = pd.read_excel("/content/gdrive/MyDrive/Colab Notebooks/분석프로젝트/data/서울시 자치구 (연도별) CCTV 설치현황_231231.xlsx",
                        skiprows=[0,1,3], usecols="C, E:N", thousands=",")
df_cctv
# Out:
#       구분  2015년 이전\n설치된 CCTV  2015년  2016년  2017년  2018년  2019년  2020년  2021년  \
# 0    종로구                 549    158    128    143    142     67    237     82
# 1    중 구                 275    236    239    372    386    155    364    419
# 2    용산구                  88     38    295    491    147    335    473    486
# 3    성동구                 190    352    278    939    457    640    483    366
# 4    광진구                 309     95     42    666    460    712    191    740
# 5   동대문구                   8     70    749    670    199    215    229    226
# 6    중랑구                 334    145    153    170    215   1074    976    507
# 7    성북구                 281    294    572    448    850    713    226    418
# 8    강북구                  37     68    210      4    375    963    569    298
# 9    도봉구                   3      0     68     80    152    149    156    552
# 10   노원구                 156    466    310    162    208    311    382    213
# ...

# %%
df_cctv.shape
# Out:
# (25, 11)

# %%
df_cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   구분                 25 non-null     object
#  1   2015년 이전
# 설치된 CCTV  25 non-null     int64
#  2   2015년              25 non-null     int64
#  3   2016년              25 non-null     int64
#  4   2017년              25 non-null     int64
#  5   2018년              25 non-null     int64
#  6   2019년              25 non-null     int64
#  7   2020년              25 non-null     int64
#  8   2021년              25 non-null     int64
#  9   2022년              25 non-null     int64
#  10  2023년              25 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.3+ KB

# %%
df_cctv.columns
# Out:
# Index(['구분', '2015년 이전\n설치된 CCTV', '2015년', '2016년', '2017년', '2018년', '2019년',
#        '2020년', '2021년', '2022년', '2023년'],
#       dtype='object')

# %%
# 구분 => 구 별, 2015년 이전\n설치된 CCTV => 2015년 이전 컬럼명 변경

# df_cctv.columns = ['구 별', '2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년',
#        '2020년', '2021년', '2022년', '2023년']

df_cctv.rename(columns={"구분":"구 별", "2015년 이전\n설치된 CCTV":"2015년 이전"}, inplace = True)
df_cctv.columns
# Out:
# Index(['구 별', '2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년',
#        '2021년', '2022년', '2023년'],
#       dtype='object')

# %%
# df_cctv[['2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년']].head()
df_cctv[['2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년']].sum(axis=1).head()
# Out:
# 0    1424
# 1    2027
# 2    1867
# 3    3339
# 4    2475
# dtype: int64

# %%
# df_cctv['2020년 이전'] = '2015년 이전'+'2015년'+'2016년'+'2017년'+'2018년'+'2019년'+'2020년'

# df_cctv['2020년 이전'] = df_cctv['2015년 이전'] + df_cctv['2015년'] + df_cctv['2016년']

df_cctv['2020년 이전'] = df_cctv[['2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년']].sum(axis=1)
df_cctv.head()
# Out:
#    구 별  2015년 이전  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구       549    158    128    143    142     67    237     82    225
# 1  중 구       275    236    239    372    386    155    364    419    137
# 2  용산구        88     38    295    491    147    335    473    486    500
# 3  성동구       190    352    278    939    457    640    483    366    233
# 4  광진구       309     95     42    666    460    712    191    740    273
#
#    2023년  2020년 이전
# 0    300      1424
# 1    135      2027
# 2    405      1867
# 3    471      3339
# 4    340      2475

# %%
df_cctv.columns
# Out:
# Index(['구 별', '2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년',
#        '2021년', '2022년', '2023년', '2020년 이전'],
#       dtype='object')

# %%
# 컬럼 : 구 별 2021년	2022년	2023년	2020년 이전

# drop()
# copy() : df_cctv = df_cctv[['구 별','2021년','2022년','2023년','2020년 이전']].copy()

df_cctv.drop(columns=['2015년 이전', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년'], inplace=True)
# df_cctv.drop(columns=df_cctv[df_cctv.columns.dirrenence(['구 별','2021년','2022년','2023년','2020년 이전'])])

# %%
df_cctv.head(3)
# Out:
#    구 별  2021년  2022년  2023년  2020년 이전
# 0  종로구     82    225    300      1424
# 1  중 구    419    137    135      2027
# 2  용산구    486    500    405      1867

# %%
df_cctv.columns
# Out:
# Index(['구 별', '2021년', '2022년', '2023년', '2020년 이전'], dtype='object')

# %%
df_cctv["cctv 총계"] = df_cctv[['2021년', '2022년', '2023년', '2020년 이전']].sum(axis=1)

df_cctv.head(2)
# Out:
#    구 별  2021년  2022년  2023년  2020년 이전  cctv 총계
# 0  종로구     82    225    300      1424     2031
# 1  중 구    419    137    135      2027     2718

# %%
# 구 별 cctv 가장 적게 설치되어 있는 구

# df_cctv['cctv 총계'].min()

df_cctv[min(df_cctv['cctv 총계']) == df_cctv['cctv 총계']]
# Out:
#    구 별  2021년  2022년  2023년  2020년 이전  cctv 총계
# 0  종로구     82    225    300      1424     2031

# %%
# 구 별 cctv 가장 많이 설치되어 있는 구

df_cctv[max(df_cctv['cctv 총계']) == df_cctv['cctv 총계']]
# Out:
#     구 별  2021년  2022년  2023년  2020년 이전  cctv 총계
# 22  강남구    505    588    446      6182     7721

# %% [markdown]
# ## 서울시 거주 인구 데이터 로드

# %%
# 주민등록인구(월별)

df_seoul = pd.read_excel("/content/gdrive/MyDrive/Colab Notebooks/분석프로젝트/data/주민등록인구(월별).xlsx",
                        skiprows=[0,1], usecols="B,D,G,J", thousands=",")
df_seoul
# Out:
#    동별(2)    소계.1    소계.2   소계.3
# 0    종로구  150447  139432  11015
# 1     중구  131886  121607  10279
# 2    용산구  221508  207969  13539
# 3    성동구  284141  276847   7294
# 4    광진구  350624  334790  15834
# 5   동대문구  360472  341981  18491
# 6    중랑구  387193  381668   5525
# 7    성북구  437188  424663  12525
# 8    강북구  290909  285880   5029
# 9    도봉구  308636  306057   2579
# 10   노원구  501292  496406   4886
# 11   은평구  469870  465660   4210
# 12  서대문구  320933  306001  14932
# 13   마포구  374626  363449  11177
# 14   양천구  437217  433975   3242
# 15   강서구  566463  560679   5784
# 16   구로구  413790  390952  22838
# 17   금천구  240425  226955  13470
# 18  영등포구  397830  375090  22740
# 19   동작구  390032  378871  11161
# 20   관악구  497938  481722  16216
# 21   서초구  412073  407596   4477
# 22   강남구  560142  554651   5491
# 23   송파구  659355  653447   5908
# 24   강동구  466117  461921   4196

# %%
# 컬럼명 변경

df_seoul.columns = ['구 별','총인구','한국인','외국인']
df_seoul.head(1)
# Out:
#    구 별     총인구     한국인    외국인
# 0  종로구  150447  139432  11015

# %%
#  df_cctv['구 별'] : 중 구  ==> 중구 변경

# df_cctv.loc[1, '구 별'] = '중구'

df_cctv.iloc[1, 0] = '중구'

# %%
df_cctv.head(3)
# Out:
#    구 별  2021년  2022년  2023년  2020년 이전  cctv 총계
# 0  종로구     82    225    300      1424     2031
# 1   중구    419    137    135      2027     2718
# 2  용산구    486    500    405      1867     3258

# %%
# 어느 구에 외국인이 가장 많은가?

# df_seoul[df_seoul['외국인'].max() == df_seoul['외국인']]

df_seoul.sort_values('외국인',ascending=False)
# Out:
#      구 별     총인구     한국인    외국인
# 16   구로구  413790  390952  22838
# 18  영등포구  397830  375090  22740
# 5   동대문구  360472  341981  18491
# 20   관악구  497938  481722  16216
# 4    광진구  350624  334790  15834
# 12  서대문구  320933  306001  14932
# 2    용산구  221508  207969  13539
# 17   금천구  240425  226955  13470
# 7    성북구  437188  424663  12525
# 13   마포구  374626  363449  11177
# 19   동작구  390032  378871  11161
# 0    종로구  150447  139432  11015
# 1     중구  131886  121607  10279
# 3    성동구  284141  276847   7294
# 23   송파구  659355  653447   5908
# 15   강서구  566463  560679   5784
# 6    중랑구  387193  381668   5525
# 22   강남구  560142  554651   5491
# 8    강북구  290909  285880   5029
# 10   노원구  501292  496406   4886
# 21   서초구  412073  407596   4477
# 11   은평구  469870  465660   4210
# 24   강동구  466117  461921   4196
# 14   양천구  437217  433975   3242
# 9    도봉구  308636  306057   2579

# %%
# cctv 설치 대수 대비 범죄율 파악

# df_cctv + df_seoul merge

# concat() : 위아래(기본), 옆으로
# merge() : sql join 개념

# df_cctv.merge(df_seoul)

df_merge = pd.merge(df_cctv, df_seoul, on="구 별")

# %%
df_merge.head()
# Out:
#    구 별  2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인
# 0  종로구     82    225    300      1424     2031  150447  139432  11015
# 1   중구    419    137    135      2027     2718  131886  121607  10279
# 2  용산구    486    500    405      1867     3258  221508  207969  13539
# 3  성동구    366    233    471      3339     4409  284141  276847   7294
# 4  광진구    740    273    340      2475     3828  350624  334790  15834

# %%
# 구 별 인덱스 설정
df_merge.set_index('구 별', inplace=True)

# %%
# 1인당 cctv 비율 = cctv 총계 / 총인구

df_merge['1인당 cctv 비율'] = df_merge['cctv 총계'] / df_merge['총인구'] * 100
df_merge.head()
# Out:
#      2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인  \
# 구 별
# 종로구     82    225    300      1424     2031  150447  139432  11015
# 중구     419    137    135      2027     2718  131886  121607  10279
# 용산구    486    500    405      1867     3258  221508  207969  13539
# 성동구    366    233    471      3339     4409  284141  276847   7294
# 광진구    740    273    340      2475     3828  350624  334790  15834
#
#      1인당 cctv 비율
# 구 별
# 종로구     1.349977
# 중구      2.060871
# 용산구     1.470827
# 성동구     1.551694
# 광진구     1.091768

# %%
# 상관관계분석 :  두 변수 간에 어떤 선형적 관계를 갖고 있는지 분석
#                 총인구와 cctv 총계 어떤 관계가 있느냐?
#                 상관계수는 -1 ~ +1 값으로 나오며, -1 or +1 에 가까울수록 상관관계가 높아짐
#                 - 인 경우는 부정적인 관계, + 인 경우에는 양의 상관관계
#                 0 인 경우는 관계없음

df_merge['총인구'].corr(df_merge['cctv 총계'],method='spearman')
# Out:
# 0.5538461538461539

# %%
df_merge['외국인'].corr(df_merge['cctv 총계'],method='spearman')
# Out:
# 0.06538461538461539

# %%
# 1 인당 cctv 비율 barh
plt.figure(figsize=(12,8))
plt.title("구 별 1인당 cctv 비율")
plt.barh(y=df_merge.index, width=df_merge['1인당 cctv 비율'])
plt.xlabel('cctv 비율', fontsize=14)
plt.ylabel('구 별', fontsize=14);

# %%
df_merge['1인당 cctv 비율'].sort_values().plot.barh(figsize=(12,8))
plt.title("구 별 1인당 cctv 비율");

# %% [markdown]
# ## 5 대 범죄

# %%
df_crime = pd.read_excel("/content/gdrive/MyDrive/Colab Notebooks/분석프로젝트/data/5대범죄.xlsx",
                        skiprows=[0,1,2,4], usecols="B:D", thousands=",")
df_crime.head()
# Out:
#   자치구별(2)    발생    검거
# 0     종로구  3138  3284
# 1      중구  3071  2119
# 2     용산구  2967  2093
# 3     성동구  2194  1597
# 4     광진구  3619  2498

# %%
# 컬럼명 변경

df_crime.columns = ['구 별','범죄건','검거건']
df_crime.columns
# Out:
# Index(['구 별', '범죄건', '검거건'], dtype='object')

# %%
# 인덱스 설정 : '구 별'
df_crime.set_index('구 별',inplace = True)
df_crime.head(3)
# Out:
#       범죄건   검거건
# 구 별
# 종로구  3138  3284
# 중구   3071  2119
# 용산구  2967  2093

# %%
df_merge.merge(df_crime, left_index=True, right_index=True).head()
# Out:
#      2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인  \
# 구 별
# 종로구     82    225    300      1424     2031  150447  139432  11015
# 중구     419    137    135      2027     2718  131886  121607  10279
# 용산구    486    500    405      1867     3258  221508  207969  13539
# 성동구    366    233    471      3339     4409  284141  276847   7294
# 광진구    740    273    340      2475     3828  350624  334790  15834
#
#      1인당 cctv 비율   범죄건   검거건
# 구 별
# 종로구     1.349977  3138  3284
# 중구      2.060871  3071  2119
# 용산구     1.470827  2967  2093
# 성동구     1.551694  2194  1597
# 광진구     1.091768  3619  2498

# %%
pd.concat([df_merge, df_crime], axis=1)
# Out:
#       2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인  \
# 구 별
# 종로구      82    225    300      1424     2031  150447  139432  11015
# 중구      419    137    135      2027     2718  131886  121607  10279
# 용산구     486    500    405      1867     3258  221508  207969  13539
# 성동구     366    233    471      3339     4409  284141  276847   7294
# 광진구     740    273    340      2475     3828  350624  334790  15834
# 동대문구    226    317    585      2140     3268  360472  341981  18491
# 중랑구     507    294    644      3067     4512  387193  381668   5525
# 성북구     418    355    421      3384     4578  437188  424663  12525
# 강북구     298    797     10      2226     3331  290909  285880   5029
# 도봉구     552    557    661       608     2378  308636  306057   2579
# 노원구     213    161    637      1995     3006  501292  496406   4886
# 은평구     520    481    387      3639     5027  469870  465660   4210
# 서대문구    331    174    348      2940     3793  320933  306001  14932
# ...

# %%
# df_merge 와 df_crime 합치기

df_crime_merge = df_merge.merge(df_crime, left_index=True, right_index=True)
df_crime_merge.head()
# Out:
#      2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인  \
# 구 별
# 종로구     82    225    300      1424     2031  150447  139432  11015
# 중구     419    137    135      2027     2718  131886  121607  10279
# 용산구    486    500    405      1867     3258  221508  207969  13539
# 성동구    366    233    471      3339     4409  284141  276847   7294
# 광진구    740    273    340      2475     3828  350624  334790  15834
#
#      1인당 cctv 비율   범죄건   검거건
# 구 별
# 종로구     1.349977  3138  3284
# 중구      2.060871  3071  2119
# 용산구     1.470827  2967  2093
# 성동구     1.551694  2194  1597
# 광진구     1.091768  3619  2498

# %%
# 검거율 = 검거건 / 범죄건 * 100

df_crime_merge['검거율'] = df_crime_merge['검거건'] / df_crime_merge['범죄건'] * 100
df_crime_merge.head(2)
# Out:
#      2021년  2022년  2023년  2020년 이전  cctv 총계     총인구     한국인    외국인  \
# 구 별
# 종로구     82    225    300      1424     2031  150447  139432  11015
# 중구     419    137    135      2027     2718  131886  121607  10279
#
#      1인당 cctv 비율   범죄건   검거건         검거율
# 구 별
# 종로구     1.349977  3138  3284  104.652645
# 중구      2.060871  3071  2119   69.000326

# %%
# scatter : 두 변수 사이의 상관관계 차트

# y 축 : cctv 총계 /  x 축 : 범죄건, 검거건

plt.scatter(df_crime_merge['범죄건'], df_crime_merge['cctv 총계'])
plt.scatter(df_crime_merge['검거건'], df_crime_merge['cctv 총계'])
plt.legend(['범죄건','검거건'])
plt.xlabel("범죄건/검거건")
plt.ylabel("cctv 총계");

# %%
ax = df_crime_merge.plot.scatter(x='검거건', y='cctv 총계',color="red", s=50, label="검거")
df_crime_merge.plot.scatter(x='범죄건', y='cctv 총계', ax=ax, color="b", s=30, label="범죄")
plt.xlabel('검거건/범죄건')
# Out:
# Text(0.5, 0, '검거건/범죄건')
